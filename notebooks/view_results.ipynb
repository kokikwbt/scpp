# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set(context='notebook', font_scale=1.2)

# %%
outdir  = '../out/retail'
theta   = np.loadtxt(outdir + '/theta.txt')  # Relation
alpha_u = np.loadtxt(outdir + '/alpha_u.txt')  # Influence
alpha_i = np.loadtxt(outdir + '/alpha_i.txt')  # Popularity
loglikelihood = np.loadtxt(outdir + '/train_history.txt')

# %%
plt.plot(loglikelihood[1:])
plt.xlabel('Iteration')
plt.ylabel('Log-likelihood')
plt.show()

# %%
alpha_u.sort()
plt.plot(alpha_u[::-1])
plt.xlabel('User')
plt.ylabel(r'$\alpha_u$')
# Out:
# Text(0, 0.5, '$\\alpha_u$')
